# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import sxs
import os

# %%
catalog = sxs.load('simulations')
# Out:
# Loading SXS simulations using latest tag 'v3.0.0', published at 2025-05-14T18:17:30Z.
# Downloading to /dev/shm/.cache-nkhusid/sxs/simulations_v3.0.0.temp.json:
#   0%|          | 0/5589954 [00:00<?, ?it/s]

# %%
print("SXS:BBH:1156" in catalog)
# Out:
# True

# %%
sim = sxs.load("SXS:BBH:1156")

# %%
sim.files
# Out:
# {'Lev3:metadata.json': {'checksum': 'md5:f262f90d09c6fe04588b93b7458bbca0',
#   'size': 3363,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev3%3Ametadata.json/content'},
#  'Lev3:Strain_N2.h5': {'checksum': 'md5:6f3a74bafefbf3083c41aa817db23713',
#   'size': 6597437,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev3%3AStrain_N2.h5/content'},
#  'Lev2:Strain_N2.h5': {'checksum': 'md5:7027a6aeb74c45d7ad24879f83a9a753',
#   'size': 6917194,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev2%3AStrain_N2.h5/content'},
#  'Lev2:Strain_N2.json': {'checksum': 'md5:47fc2a0558dab949d4d8d92488ff658a',
#   'size': 2230,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev2%3AStrain_N2.json/content'},
#  'Lev3:Strain_N2.json': {'checksum': 'md5:7d54ae447689a228dd9f95dbbe276488',
#   'size': 2230,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev3%3AStrain_N2.json/content'},
#  'Lev3:ExtraWaveforms.h5': {'checksum': 'md5:2ba87054a75e4aa301088fa416e9d207',
#   'size': 54027598,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev3%3AExtraWaveforms.h5/content'},
#  'Lev1:ExtraWaveforms.json': {'checksum': 'md5:fed3f5a4f5d071c31fbf2274382f079b',
#   'size': 17435,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev1%3AExtraWaveforms.json/content'},
#  'Lev2:metadata.json': {'checksum': 'md5:fc34b64e0b50bbc918c8bbdd3652f527',
#   'size': 3354,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev2%3Ametadata.json/content'},
#  'Lev1:ExtraWaveforms.h5': {'checksum': 'md5:c6494215d2eaf0aa45762f39ef69e333',
#   'size': 59916612,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev1%3AExtraWaveforms.h5/content'},
#  'Lev3:ExtraWaveforms.json': {'checksum': 'md5:d47b0f79e3b6a90896db7fe4153d3c6b',
#   'size': 17449,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev3%3AExtraWaveforms.json/content'},
#  'Lev1:Horizons.h5': {'checksum': 'md5:95871abf1a44494c75e586da66cd0619',
#   'size': 5320214,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev1%3AHorizons.h5/content'},
#  'Lev1:metadata.json': {'checksum': 'md5:a817ad41ffd06316fc63787774220cf0',
#   'size': 3365,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev1%3Ametadata.json/content'},
#  'Lev3:Horizons.h5': {'checksum': 'md5:c13cd5c082da3fe968542a3b6fd65e53',
#   'size': 5168917,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev3%3AHorizons.h5/content'},
#  'Lev1:Strain_N2.h5': {'checksum': 'md5:bbb3ed1e4f1442f99c1eacca3a4f3340',
#   'size': 7362323,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev1%3AStrain_N2.h5/content'},
#  'Lev1:Strain_N2.json': {'checksum': 'md5:e66106fd5548feaa66301d790edc42d7',
#   'size': 2228,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev1%3AStrain_N2.json/content'},
#  'Lev2:ExtraWaveforms.h5': {'checksum': 'md5:921754c706701a6f27805f43a65a551d',
#   'size': 56199169,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev2%3AExtraWaveforms.h5/content'},
#  'Lev2:ExtraWaveforms.json': {'checksum': 'md5:4d08089f22abacb22eace0daee9eed83',
#   'size': 17449,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev2%3AExtraWaveforms.json/content'},
#  'Lev2:Horizons.h5': {'checksum': 'md5:f4b10848a8b24633066639283b89a4c6',
#   'size': 5264632,
#   'link': 'https://data.caltech.edu/api/records/7cxk4-h4610/files/Lev2%3AHorizons.h5/content'}}

# %%
sxs.utilities.lvcnr.conversion.convert_simulation('/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1156',
                                                  '/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1156_l2m2',
                                                  waveform_name='Strain_N2.h5',
                                                  resolution=3,
                                                  modes='22only')
# Out:
# sxs.utilities.lvcnr.convert_simulation(
#     sxs_data_path='/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1156',
#     out_path='/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1156_l2m2',
#     truncation_time=None,
#     resolution=3,
#     modes='22only',
#     tolerance=1e-06,
#     quiet=False
# )
# Starting at 12:40PM EDT on Jun 24, 2026
# Converting SXS:BBH:1156
# Extrapolation order: Extrapolated_N2
# Output filename is '/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1156_l2m2/SXS_BBH_1156_Res3.h5'
# Computing ['mass1-vs-time']
# Computing ['mass2-vs-time']
# Computing ['remnant-mass-vs-time']
# Computing ['spin1x-vs-time', 'spin1y-vs-time', 'spin1z-vs-time']
# Computing ['spin2x-vs-time', 'spin2y-vs-time', 'spin2z-vs-time']
# Computing ['remnant-spinx-vs-time', 'remnant-spiny-vs-time', 'remnant-spinz-vs-time']
# Computing ['position1x-vs-time', 'position1y-vs-time', 'position1z-vs-time']
# Computing ['position2x-vs-time', 'position2y-vs-time', 'position2z-vs-time']
# Computing ['remnant-positionx-vs-time', 'remnant-positiony-vs-time', 'remnant-positionz-vs-time']
# Computing ['nhatx-vs-time', 'nhaty-vs-time', 'nhatz-vs-time']
# Computing ['Omega-vs-time']
# Computing ['LNhatx-vs-time', 'LNhaty-vs-time', 'LNhatz-vs-time']
# Writing horizon data to '/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1156_l2m2/SXS_BBH_1156_Res3.h5'
# Writing metadata
# No VersionHist.ver found. Data being converted is version 0.
# Finishing at 12:40PM EDT on Jun 24, 2026
# Writing log

# %%
h = sim.h

# Check the (2,0) mode — should show a non-oscillatory step across merger
h20 = h[:, h.index(2, 0)]
h21 = h[:, h.index(2, 1)]
h22 = h[:, h.index(2, 2)]
import matplotlib.pyplot as plt

plt.plot(h.t, h21.real, ls=':', alpha=0.7, label='(2,2)')
# plt.plot(h.t, h21.real, ls='--', alpha=0.7, label='(2,1)')
plt.plot(h.t, h20.real, alpha=0.8, label='(2,0)')

plt.xlim(7500)
plt.xlabel("t/M")
plt.ylabel("Re[$h_{(2,m)}$]")
# plt.title("Memory mode (2,0)")
plt.legend()

# %%
sxs.utilities.lvcnr.conversion.convert_simulation?
# Out:
# Signature:
# sxs.utilities.lvcnr.conversion.convert_simulation(
#     sxs_data_path,
#     out_path,
#     waveform_name=None,
#     out_waveform_name=None,
#     truncation_time=None,
#     resolution=None,
#     modes=8,
#     tolerance=1e-06,
#     quiet=False,
# )
# Docstring:
# Convert a simulation from the SXS BBH catalog into the LVC format.
#
# This function outputs a file in LVC format named SXS_BBH_####_Res#.h5 in
# out_path.
#
# Note that this function is essentially a wrapper for
# `SimulationConverter.convert`.  If you have very many systems to convert, it is
# significantly faster to create the SimulationConverter object once, and then
# call the `convert` method for each system.
#
# Parameters
# ----------
# sxs_data_path : string
#     Path to directory containing waveform file,
#     Horizons.h5, and metadata.txt or metadata.json files.
# out_path : string
#     Path where LVC-format file is to be output
# waveform_name : string
#     Name of waveform to load in sxs_data_path. If not specified,
#     will try to load Strain_N2.h5 or rhOverM_Asymptotic_GeometricUnits_CoM.h5
# out_waveform_name : string
#     Name of LVC-format file to output in out_path. If not specified,
#     will use SXS_BBH_####_Res#.h5
# truncation_time : {None, float}, optional
#     If specified, truncate time series at this time instead of at the reference time
# resolution : {None, int}, optional
#     Integer giving the resolution (Lev) of the data to convert.  If this is not given,
#     the resolution is determined automatically from sxs_data_path.
# modes : {int, '22only'}, optional
#     Modes to be placed in the output file.  Passing '22only' results in the (2,2)
#     and (2,-2) modes being output.  Otherwise, each (l,m) mode up to and including
#     the given l value will be output.  Note that for backwards compatibility, 'all'
#     is also supported, and is equivalent to the default value of `8`.
# tolerance : float, optional
#     Target tolerance used in `sxs.utilities.greedy_spline.minimal_indices`.
# quiet : bool, optional
#     If False (the default), echo each line of the log as it is created; otherwise
#     just store the final log in the output file.
# File:      ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/sxs/utilities/lvcnr/conversion.py
# Type:      function
