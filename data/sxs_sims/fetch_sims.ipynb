# %%
import sxs
import os

# %%
catalog = sxs.load('records')
# Out:
# An error occurred when trying to access <https://data.black-holes.org/catalog.json>.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/sxs/catalog/catalog.py:85, in Catalog.load(cls, download)
#      84 try:
# ---> 85     download_file(cls.url, temp_json, progress=progress, if_newer=if_newer)
#      86 except Exception as e:
#
# File ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/sxscatalog/utilities/downloads.py:63, in download_file(url, path, progress, if_newer)
#      62     pass
# ---> 63 r.raise_for_status()
#      64 raise RuntimeError()  # Will only happen if the response was not strictly an error
#
# File ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
catalog.records
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 catalog.records
#
# AttributeError: 'Simulations' object has no attribute 'records'

# %%
path = '/mnt/home/nkhusid/spec_inj/data/sxs_sims/SXS_BBH_1155'
sxs.utilities.lvcnr.convert_simulation(path,
                                       out_path=path,
                                       resolution=3,
                                       modes='22only',)
# Out:
# An error occurred when trying to access <https://data.black-holes.org/catalog.json>.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/sxs/catalog/catalog.py:85, in Catalog.load(cls, download)
#      84 try:
# ---> 85     download_file(cls.url, temp_json, progress=progress, if_newer=if_newer)
#      86 except Exception as e:
#
# File ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/sxscatalog/utilities/downloads.py:63, in download_file(url, path, progress, if_newer)
#      62     pass
# ---> 63 r.raise_for_status()
#      64 raise RuntimeError()  # Will only happen if the response was not strictly an error
#
# File ~/.virtualenvs/rd_igwn/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
sim = sxs.load('SXS:BBH:1353', download=True, dir='/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1353')

# %%
sim.files
# Out:
# {'Lev3:Strain_N2.h5': {'checksum': 'md5:b4aa68452bc23ee3ca8232fb42a5bd72',
#   'size': 2005571,
#   'link': 'https://data.caltech.edu/api/records/9xgkm-53849/files/Lev3%3AStrain_N2.h5/content'},
#  'Lev3:metadata.json': {'checksum': 'md5:cabe415147f58aa53886f4e9ec4cfad2',
#   'size': 3325,
#   'link': 'https://data.caltech.edu/api/records/9xgkm-53849/files/Lev3%3Ametadata.json/content'},
#  'Lev2:ExtraWaveforms.h5': {'checksum': 'md5:1eab428c6d5b7e3c5ee974c79e5000ac',
#   'size': 18339203,
#   'link': 'https://data.caltech.edu/api/records/9xgkm-53849/files/Lev2%3AExtraWaveforms.h5/content'},
#  'Lev2:ExtraWaveforms.json': {'checksum': 'md5:34b6c8b6a424c83dbddd2245ff8f4104',
#   'size': 17449,
#   'link': 'https://data.caltech.edu/api/records/9xgkm-53849/files/Lev2%3AExtraWaveforms.json/content'},
#  'Lev2:Horizons.h5': {'checksum': 'md5:dd08f7fe73701942dd14cfbef75d3dfe',
#   'size': 1424705,
# ...

# %%
for k in sim.files.keys():
    filename = sim.files[k]['link'].split('/content')[0]
    print(filename)
    os.system(f"wget -P /mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1353 \"{filename}\"")
# Out:
# https://data.caltech.edu/api/records/9xgkm-53849/files/Lev3%3AStrain_N2.h5
# --2025-12-17 02:20:14--  https://data.caltech.edu/api/records/9xgkm-53849/files/Lev3%3AStrain_N2.h5
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 640 [application/json]
# Saving to: ‘/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1353/Lev3:Strain_N2.h5’
#
#      0K                                                       100% 1.85M=0s
#
# 2025-12-17 02:20:14 (1.85 MB/s) - ‘/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1353/Lev3:Strain_N2.h5’ saved [640/640]
#
# --2025-12-17 02:20:14--  https://data.caltech.edu/api/records/9xgkm-53849/files/Lev3%3Ametadata.json
# https://data.caltech.edu/api/records/9xgkm-53849/files/Lev3%3Ametadata.json
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# ...

# %%
sim = sxs.load('SXS:BBH:0623', download=True, dir='/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_0623')

# %%
for k in sim.files.keys():
    filename = sim.files[k]['link'].split('/content')[0]
    print(filename)
    os.system(f"wget -P /mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_0623 \"{filename}\"")
# Out:
# https://data.caltech.edu/api/records/jt4d2-91n85/files/Lev0%3AStrain_N2.json
# --2025-12-17 02:20:51--  https://data.caltech.edu/api/records/jt4d2-91n85/files/Lev0%3AStrain_N2.json
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 641 [application/json]
# Saving to: ‘/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_0623/Lev0:Strain_N2.json’
#
#      0K                                                       100% 1.20M=0.001s
#
# 2025-12-17 02:20:51 (1.20 MB/s) - ‘/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_0623/Lev0:Strain_N2.json’ saved [641/641]
#
# --2025-12-17 02:20:52--  https://data.caltech.edu/api/records/jt4d2-91n85/files/Lev0%3AExtraWaveforms.h5
# https://data.caltech.edu/api/records/jt4d2-91n85/files/Lev0%3AExtraWaveforms.h5
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# ...

# %%
sim = sxs.load('SXS:BBH:1227', download=True, dir='/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1227')
# Out:
# Loading SXS simulations using latest tag 'v3.0.0', published at 2025-05-14T18:17:30Z.

# %%
for k in sim.files.keys():
    filename = sim.files[k]['link'].split('/content')[0]
    print(filename)
    os.system(f"wget -P /mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1227 \"{filename}\"")
# Out:
# https://data.caltech.edu/api/records/16d1a-faz49/files/Lev4%3AExtraWaveforms.json
# --2025-12-17 02:18:23--  https://data.caltech.edu/api/records/16d1a-faz49/files/Lev4%3AExtraWaveforms.json
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 657 [application/json]
# Saving to: ‘/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1227/Lev4:ExtraWaveforms.json’
#
#      0K                                                       100% 2.32M=0s
#
# 2025-12-17 02:18:24 (2.32 MB/s) - ‘/mnt/home/nkhusid/spec_inj/sxs_sims/SXS_BBH_1227/Lev4:ExtraWaveforms.json’ saved [657/657]
#
# --2025-12-17 02:18:24--  https://data.caltech.edu/api/records/16d1a-faz49/files/Lev3%3AExtraWaveforms.h5
# https://data.caltech.edu/api/records/16d1a-faz49/files/Lev3%3AExtraWaveforms.h5
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# ...
