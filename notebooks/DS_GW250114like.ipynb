# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import arviz as az

# import h5py
import glob

import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")

import ringdown as rd

# %% [markdown]
# ## 220

# %% [markdown]
# ### df_pre = 0

# %%
collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220/tgr/220+d221_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre0/engine/*/result.nc')
collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre0/engine/*/result.nc')
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
collo.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
collf.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
# Out:
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)

# %%
dfo = collo.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
dff = collf.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
sns.histplot(dfo, x='df_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='df_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta f_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.histplot(dfo, x='dg_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='dg_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta \gamma_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.kdeplot(dfo[dfo['run'] <= 0], x='df_221', y='dg_221', hue='run', linewidths=3, levels=[0.1], palette='Oranges_r', common_norm=False)
sns.kdeplot(dff[dff['run'] <= 0], x='df_210', y='dg_210', hue='run', linewidths=3, levels=[0.1], palette='Blues_r', common_norm=False)

plt.axvline(0, color='k', ls=':')
plt.axhline(0, color='k', ls=':')

plt.xlabel('$\delta f_{\ell m n}$')
plt.ylabel('$\delta \gamma_{\ell m n}$')
# Out:
# Text(0, 0.5, '$\\delta \\gamma_{\\ell m n}$')

# %% [markdown]
# ### df_pre = -0.5

# %%
collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220/tgr/220+d221_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre-0.5/engine/*/result.nc')
collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre-0.5/engine/*/result.nc')
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
collo.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
collf.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
# Out:
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)

# %%
dfo = collo.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
dff = collf.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
sns.histplot(dfo, x='df_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='df_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta f_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.histplot(dfo, x='dg_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='dg_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta \gamma_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.kdeplot(dfo[dfo['run'] <= 0], x='df_221', y='dg_221', hue='run', linewidths=3, levels=[0.1], palette='Oranges_r', common_norm=False)
sns.kdeplot(dff[dff['run'] <= 0], x='df_210', y='dg_210', hue='run', linewidths=3, levels=[0.1], palette='Blues_r', common_norm=False)

plt.axvline(0, color='k', ls=':')
plt.axhline(0, color='k', ls=':')

plt.xlabel('$\delta f_{\ell m n}$')
plt.ylabel('$\delta \gamma_{\ell m n}$')
# Out:
# Text(0, 0.5, '$\\delta \\gamma_{\\ell m n}$')

# %% [markdown]
# ## 220+210

# %% [markdown]
# ### df_pre = 0

# %%
collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+210/tgr/220+d221_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre0/engine/*/result.nc')
collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+210/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre0/engine/*/result.nc')
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
collo.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
collf.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
# Out:
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)

# %%
dfo = collo.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
dff = collf.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
sns.histplot(dfo, x='df_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='df_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta f_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.histplot(dfo, x='dg_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='dg_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta \gamma_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.kdeplot(dfo[dfo['run'] <= 0], x='df_221', y='dg_221', hue='run', linewidths=3, levels=[0.1], palette='Oranges_r', common_norm=False)
sns.kdeplot(dff[dff['run'] <= 0], x='df_210', y='dg_210', hue='run', linewidths=3, levels=[0.1], palette='Blues_r', common_norm=False)

plt.axvline(0, color='k', ls=':')
plt.axhline(0, color='k', ls=':')

plt.xlabel('$\delta f_{\ell m n}$')
plt.ylabel('$\delta \gamma_{\ell m n}$')
# Out:
# Text(0, 0.5, '$\\delta \\gamma_{\\ell m n}$')

# %% [markdown]
# ### df_pre = -0.5

# %%
collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+210/tgr/220+d221_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre-0.5/engine/*/result.nc')
collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+210/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre-0.5/engine/*/result.nc')
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
collo.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
collf.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
# Out:
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)

# %%
dfo = collo.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
dff = collf.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
sns.histplot(dfo, x='df_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='df_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta f_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.histplot(dfo, x='dg_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='dg_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta \gamma_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.kdeplot(dfo[dfo['run'] <= 0], x='df_221', y='dg_221', hue='run', linewidths=3, levels=[0.1], palette='Oranges_r', common_norm=False)
sns.kdeplot(dff[dff['run'] <= 0], x='df_210', y='dg_210', hue='run', linewidths=3, levels=[0.1], palette='Blues_r', common_norm=False)

plt.axvline(0, color='k', ls=':')
plt.axhline(0, color='k', ls=':')

plt.xlabel('$\delta f_{\ell m n}$')
plt.ylabel('$\delta \gamma_{\ell m n}$')
# Out:
# Text(0, 0.5, '$\\delta \\gamma_{\\ell m n}$')

# %% [markdown]
# ## 220+221

# %% [markdown]
# ### df_pre = 0

# %%
collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+221/tgr/220+d221_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre0/engine/*/result.nc')
collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+221/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre0/engine/*/result.nc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+221/tgr/220+d221_DS_GW250114Kerr_dtaupre0_dfpre0_fmin10Hz_ppSNR20/engine/*/result.nc')
#       2 collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+221/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20/engine/*/result.nc')
#
# File ~/src/rd-igwn-GW250114/ringdown/result.py:1893, in ResultCollection.from_netcdf(cls, path_input, index, config, load_h_det_mode, produce_h_det, progress, max_length, **kws)
#    1891     paths = path_input
#    1892 if len(paths) == 0:
# -> 1893     raise ValueError("No results found.")
#    1894 if index is not None and len(index) != len(paths):
#    1895     for idx in index:
#
# ValueError: No results found.

# %%
collo.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
collf.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
# Out:
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)

# %%
dfo = collo.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
dff = collf.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
sns.histplot(dfo, x='df_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='df_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta f_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.histplot(dfo, x='dg_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='dg_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta \gamma_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.kdeplot(dfo[dfo['run'] <= 0], x='df_221', y='dg_221', hue='run', linewidths=3, levels=[0.1], palette='Oranges_r', common_norm=False)
sns.kdeplot(dff[dff['run'] <= 0], x='df_210', y='dg_210', hue='run', linewidths=3, levels=[0.1], palette='Blues_r', common_norm=False)

plt.axvline(0, color='k', ls=':')
plt.axhline(0, color='k', ls=':')

plt.xlabel('$\delta f_{\ell m n}$')
plt.ylabel('$\delta \gamma_{\ell m n}$')
# Out:
# Text(0, 0.5, '$\\delta \\gamma_{\\ell m n}$')

# %% [markdown]
# ### df_pre = -0.5

# %%
collo = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+221/tgr/220+d221_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre-0.5/engine/*/result.nc')
collf = rd.ResultCollection.from_netcdf('/mnt/home/nkhusid/ceph/spec_inj/DS/220+221/tgr/220+d210_DS_GW250114Kerr_dtaupre0_fmin10Hz_ppSNR20_dfpre-0.5/engine/*/result.nc')
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
collo.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
collf.reindex_by_t0(reference_time=1126259462.423, reference_mass=collo[0].config['model']['m_min'] * 2, decimals=0)
# Out:
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)
# WARNING:ringdown.utils.utils:overwriting reference time (1126259462.423)

# %%
dfo = collo.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
dff = collf.get_parameter_dataframe(ndraw=500, progress=True, prng=13)
# Out:
# results:   0%|          | 0/9 [00:00<?, ?it/s]
# results:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
sns.histplot(dfo, x='df_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='df_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta f_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.histplot(dfo, x='dg_221', element='step', alpha=0, palette='Oranges_r', hue='run', lw=3, bins=30)
sns.histplot(dff, x='dg_210', element='step', alpha=0, palette='Blues_r', hue='run', lw=3, bins=30)

plt.xlabel('$\delta \gamma_{\ell m n}$')

plt.axvline(0, ls='--', color='pink', lw=2.5)

# %%
sns.kdeplot(dfo[dfo['run'] <= 0], x='df_221', y='dg_221', hue='run', linewidths=3, levels=[0.1], palette='Oranges_r', common_norm=False)
sns.kdeplot(dff[dff['run'] <= 0], x='df_210', y='dg_210', hue='run', linewidths=3, levels=[0.1], palette='Blues_r', common_norm=False)

plt.axvline(0, color='k', ls=':')
plt.axhline(0, color='k', ls=':')

plt.xlabel('$\delta f_{\ell m n}$')
plt.ylabel('$\delta \gamma_{\ell m n}$')
# Out:
# Text(0, 0.5, '$\\delta \\gamma_{\\ell m n}$')
